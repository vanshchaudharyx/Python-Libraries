# %% [markdown]
# <a href="https://colab.research.google.com/github/vanshchaudharyx/Python-Libraries/blob/main/Numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **NUMPY**
# <br>Used for mathematical operations
# <br>It is fast than list.
# <br>p=[10,20,30,40]
# <br>Pyhton list --->data large --> slow
# <br>Uses More Memory
# <br>Mathematical operations are not use direct
# <br>------------------------<br>
#
# <br>Numpy array
# <br>-->
# <br>Fast
# <br>Memory effiecient
# <br>Machine Learning
# <br>Data Science
# <br>Deep Learning
# <br>Image Processing
# <br>Medical Analysis
#
# <br>Python-->numpy function -->C Language Backend --> Fast output
# <br>-----------------------------<br>
# Colab--> import numpy as np recommended<br>
# np.array()-----> important function<br>
# python List,Tuple,nested list---> convert in to nd array<br>

# %%
import numpy as np

# %%
print (np.__version__)
# Out:
# 2.0.2

# %%
print(type(np))
# OP----<class 'module'>
# Out:
# <class 'module'>

# %%
m=[10,20,30,40,50]

# %%
arr=np.array(m)
print(type(m))
arr=np.array(m)
print(arr)
print(type(arr))
# Out:
# <class 'list'>
# [10 20 30 40 50]
# <class 'numpy.ndarray'>

# %% [markdown]
# How to direct list to array

# %%
arr=np.array([10,20,30,40,50])
print(arr)
print(type(arr))
# Out:
# [10 20 30 40 50]
# <class 'numpy.ndarray'>

# %%
tup=(10,20,30,40,50)
arr=np.array(tup)
print(arr)
print(type(arr))
# Out:
# [10 20 30 40 50]
# <class 'numpy.ndarray'>

# %%
arr=np.array(['Abhi','Rudra','Ram'])
print(arr)
# Out:
# ['Abhi' 'Rudra' 'Ram']

# %%
list=[10.5,20.5,30.5,40.5,50.5]
arr=np.array(list)
print(arr)
print(type(arr))
# Out:
# [10.5 20.5 30.5 40.5 50.5]
# <class 'numpy.ndarray'>

# %%
arr=np.array(['Vansh',90000000])
print(arr)
# Out:
# ['Vansh' '90000000']
